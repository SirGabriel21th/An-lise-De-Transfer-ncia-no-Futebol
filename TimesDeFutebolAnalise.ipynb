# %%
# Importar a biblioteca que será utilizada no estudo
import pandas as pd

# %%
# O Dataset é sobre os gastos com transferencias de times de futebol nos anos de 2000 até 2008
# Dados importados para o Dataframe

df = pd.read_csv("/content/foottransfer.csv")

# %%
# Visualização do Dataframe 
df.head(10)
# Out:
#                 Name          Position  Age       Team_from     League_from  \
# 0          Luís Figo      Right Winger   27    FC Barcelona          LaLiga
# 1      Hernán Crespo    Centre-Forward   25           Parma         Serie A
# 2      Marc Overmars       Left Winger   27         Arsenal  Premier League
# 3  Gabriel Batistuta    Centre-Forward   31      Fiorentina         Serie A
# 4     Nicolas Anelka    Centre-Forward   21     Real Madrid          LaLiga
# 5      Rio Ferdinand       Centre-Back   22        West Ham  Premier League
# 6   Flávio Conceicao  Central Midfield   26  Dep. La Coruña          LaLiga
# 7     Savo Milosevic    Centre-Forward   26   Real Zaragoza          LaLiga
# 8    David Trézéguet    Centre-Forward   22          Monaco         Ligue 1
# 9      Claudio López    Centre-Forward   25     Valencia CF          LaLiga
#
#         Team_to       League_to     Season  Market_value  Transfer_fee
# ...

# %%
# Mostra as últimas 10 linhas do Dataframe
df.tail(10)
# Out:
#                      Name            Position  Age       Team_from  \
# 4690        Marco Carraro  Defensive Midfield   20           Inter
# 4691       Jonathan Ikoné  Attacking Midfield   20        Paris SG
# 4692  Giangiacomo Magnani         Centre-Back   22        Juventus
# 4693  Giangiacomo Magnani         Centre-Back   22         Perugia
# 4694         Evan N'Dicka         Centre-Back   18      AJ Auxerre
# 4695        Jasmin Kurtic  Attacking Midfield   29        Atalanta
# 4696            Tchê Tchê    Central Midfield   25       Palmeiras
# 4697        Silvan Widmer          Right-Back   25  Udinese Calcio
# 4698           Yuya Osako      Second Striker   28      1. FC Köln
# 4699         Kyle Bartley         Centre-Back   27         Swansea
#
#        League_from        Team_to     League_to     Season  Market_value  \
# 4690       Serie A       Atalanta       Serie A  2018-2019      800000.0
# 4691       Ligue 1     LOSC Lille       Ligue 1  2018-2019      700000.0
# ...

# %%
# Verificar quais são os tipos de dados para que eles já possam ser trabalhados corretamente ou possivelmente corrigidos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4700 entries, 0 to 4699
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          4700 non-null   object
#  1   Position      4700 non-null   object
#  2   Age           4700 non-null   int64
#  3   Team_from     4700 non-null   object
#  4   League_from   4700 non-null   object
#  5   Team_to       4700 non-null   object
#  6   League_to     4700 non-null   object
#  7   Season        4700 non-null   object
#  8   Market_value  3440 non-null   float64
#  9   Transfer_fee  4700 non-null   int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 367.3+ KB

# %%
# Verificar quais são os tipos de dados para que eles já possam ser trabalhados corretamente ou possivelmente corrigidos
df.dtypes
# Out:
# Name             object
# Position         object
# Age               int64
# Team_from        object
# League_from      object
# Team_to          object
# League_to        object
# Season           object
# Market_value    float64
# Transfer_fee      int64
# dtype: object

# %%
# Verificação se temos valores nulos (Not a Number/ NaN)
df.isnull().value_counts()
# Out:
# Name   Position  Age    Team_from  League_from  Team_to  League_to  Season  Market_value  Transfer_fee
# False  False     False  False      False        False    False      False   False         False           3440
#                                                                             True          False           1260
# dtype: int64

# %%
# Identificação de valores nulos mais aprofundada
df['Market_value'].isnull().value_counts()
# Out:
# False    3440
# True     1260
# Name: Market_value, dtype: int64

# %%
# Levando em consideração que temos 1260 células com valores nulos, vou excluir a coluna, visto que também não efetuarei nenhum estudo com ela hoje.
df.drop(columns=['Market_value'])
# Out:
#                    Name            Position  Age       Team_from  \
# 0             Luís Figo        Right Winger   27    FC Barcelona
# 1         Hernán Crespo      Centre-Forward   25           Parma
# 2         Marc Overmars         Left Winger   27         Arsenal
# 3     Gabriel Batistuta      Centre-Forward   31      Fiorentina
# 4        Nicolas Anelka      Centre-Forward   21     Real Madrid
# ...                 ...                 ...  ...             ...
# 4695      Jasmin Kurtic  Attacking Midfield   29        Atalanta
# 4696          Tchê Tchê    Central Midfield   25       Palmeiras
# 4697      Silvan Widmer          Right-Back   25  Udinese Calcio
# 4698         Yuya Osako      Second Striker   28      1. FC Köln
# 4699       Kyle Bartley         Centre-Back   27         Swansea
#
#          League_from        Team_to     League_to     Season  Transfer_fee
# 0             LaLiga    Real Madrid        LaLiga  2000-2001      60000000
# ...

# %%
# Atè 50% dos jogadores tem a idade menor que 24 anos
df.describe()
# Out:
#                Age  Market_value  Transfer_fee
# count  4700.000000  3.440000e+03  4.700000e+03
# mean     24.338723  8.622469e+06  9.447586e+06
# std       3.230809  8.795181e+06  1.043772e+07
# min       0.000000  5.000000e+04  8.250000e+05
# 25%      22.000000  3.500000e+06  4.000000e+06
# 50%      24.000000  6.000000e+06  6.500000e+06
# 75%      27.000000  1.000000e+07  1.082000e+07
# max      35.000000  1.200000e+08  2.220000e+08

# %%
# O time Internazionale da Itália é a instituição que mais se movimentou no período do dataframe
# seguido por Chelsea e Manchester City no Top 3
df['Team_to'].value_counts()
# Out:
# Inter              97
# Chelsea            96
# Man City           94
# Spurs              93
# Juventus           87
#                    ..
# Spartak V.          1
# Tiburones Rojos     1
# Pohang Steelers     1
# FCS Bucharest       1
# SPAL                1
# Name: Team_to, Length: 325, dtype: int64

# %%
# A Barclays Premier League é a liga de futebol mais valiosa do mundo atualmente, com um agregado de 9,08 Bilhôes de Euros
# e o dataframe demonstra que a movimentação de jogadores em transferências sempre foi altíssima  
df['League_to'].value_counts()
# Out:
# Premier League    1256
# Serie A            739
# LaLiga             525
# 1.Bundesliga       422
# Ligue 1            397
#                   ...
#  Libya               1
#  Romania             1
#  Sweden              1
#  Denmark             1
# Eliteserien          1
# Name: League_to, Length: 65, dtype: int64

# %%
# Centroavente , zagueiro e meiocampista são os mais movimentados no período de transferência
df['Position'].value_counts()
# Out:
# Centre-Forward        1218
# Centre-Back            714
# Central Midfield       487
# Attacking Midfield     426
# Defensive Midfield     411
# Right Winger           305
# Left Winger            267
# Left-Back              225
# Right-Back             181
# Goalkeeper             180
# Second Striker         130
# Left Midfield           87
# Right Midfield          63
# Forward                  3
# Sweeper                  1
# Defender                 1
# Midfielder               1
# Name: Position, dtype: int64

# %%
# Para melhor visualização utilizei o gráfico barh

# %matplotlib inline
df['Position'].value_counts().plot.barh(color='Green')

# %%
# Um total de 44.403.655.000 Euros gastos
df['Transfer_fee'].sum()
# Out:
# 44403655000

# %%
# Verificação dos times que mais gastaram durante o período
dfmoney = df.groupby('Team_to')['Transfer_fee'].sum()

# %%
dfmoney.head(10)
# Out:
# Team_to
# 1. FC Köln         41500000
# 1.FC K'lautern     14300000
# 1.FSV Mainz 05     35800000
# 1860 Munich         5575000
# AC Milan          941350000
# AEK Athens          6500000
# AFC Ajax          215250000
# AJ Auxerre         24300000
# AS Livorno          6000000
# AS Roma           826380000
# Name: Transfer_fee, dtype: int64

# %%
# Observando os times que mais gastaram , diretamente no Top 5 , três deles são ingleses , lembrando que hoje é a liga mais rica do mundo.
dfmoney.sort_values()
# Out:
# Team_to
# Ascoli               900000
# M. Tel Aviv         1000000
# Al-Ittihad          1000000
# Chelsea U23         1000000
# Royal Antwerp       1000000
#                     ...
# Man Utd          1497360000
# FC Barcelona     1673040000
# Real Madrid      1680650000
# Man City         1800520000
# Chelsea          1820650000
# Name: Transfer_fee, Length: 325, dtype: int64
